# %%
from VerifyObjects import *
from VerifyRelation import *
from Verifier import *

# %% [markdown]
# # Example2 Accelerated Gradient Descent

# %% [markdown]
# ## 1. Positiveness of $\theta_k$

# %%
known_truth = {eq_refl,eq_sym,eq_to_le,eq_trans}
Prop = known_truth.copy()
Var = set()


#Basic Setting
t = ScalarSequence('t') #theta

x = Sequence('x')
y = Sequence('y')


X = Sequence('X') #For equivalent formulation
Y = Sequence('Y')
Z = Sequence('Z')


f = Function('f')
g = Operator('g') # Grdaient f
k = IterationCount('k')
L = Scalar('L')   # L-smoothness

# %%
#Define theta
t = ScalarSequence('t')

assumption_t0 = Equal(t(0),1)
def t_def(n):
    return Equal(t(n+1), 1/2*(Sqrt(4*t(n)*t(n)+1) +1))

Prop.add(assumption_t0)
Prop.add(t_def)



def t_rel(n):
    return Equal( t(n+1)*t(n+1) - t(n+1), t(n)*t(n) )

proof_t0 = []

# %%
#verify the equation for theta
propadd_assumption(t_def)
propadd_intro(t_def,arb_n)


verify(t_rel,[t_def(arb_n)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      16     if callable(prop):
# ---> 17         try: return verify_forall_scalar(prop,proof)
#      18         except:
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_forall_scalar(prop, proof)
#      41     #arb_num = Scalar('arb_num')  #represents arbitrary number and vector
# ---> 42     return verify(prop(arb_n), proof)
#      43
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      22     if isinstance(prop, Equal):
# ---> 23         return verify_equality(prop, proof)
#      24     if isinstance(prop, le):
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_equality(eq, proof)
#      78       else:
# ---> 79         raise TypeError( f'Should first verify the current step: {step}')
#      80
#
# TypeError: Should first verify the current step: t_{1+arb_n} = 0.5 * ( 1+(1+4 * t_{arb_n}**{2})**{0.5} )
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      18         except:
# ---> 19             try: return verify_forall_vector(prop,proof)
#      20             except: raise TypeError(f'wrong input type: {type(prop)}')
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_forall_vector(prop, proof)
#      45     arb_vec = Vector('arb_vec')
# ---> 46     return verify(prop(arb_vec), proof)
#      47
#
# <ipython-input-47-6044167c9140> in t_rel(n)
#      13 def t_rel(n):
# ---> 14     return Equal( t(n+1)*t(n+1) - t(n+1), t(n)*t(n) )
#      15
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\VerifyObjects.py in __add__(self, other)
#      20         else:
# ---> 21             raise TypeError( "Can't add " +  str(self) + ' of type ' + str(type(self)) + " with " + str(other) + ' of type ' + str(type(other)) )
#      22
#
# TypeError: Can't add arb_vec of type <class 'VerifyObjects.Vector'> with 1 of type <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-7626ead98920> in <module>
#       4
#       5
# ----> 6 verify(t_rel,[t_def(arb_n)])
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      18         except:
#      19             try: return verify_forall_vector(prop,proof)
# ---> 20             except: raise TypeError(f'wrong input type: {type(prop)}')
#      21
#      22     if isinstance(prop, Equal):
#
# TypeError: wrong input type: <class 'function'>

# %%
#Goal : to prove the positivity of theta, i.e.
def t_pos(n):
    return lt(0,t(n))

Prop = known_truth #Start with known truth

propadd_assumption(assumption_t0) #Assume t_0 = 1
propadd_assumption(t_def) #Assume the equation corresponding to t's definition
propadd_intro(t_def,0) #Specifically we consider t(0), t(arb_n) to be true
propadd_intro(t_def, arb_n)

propadd_assumption(sqrt_nonneg) # sqrt is nonneg
propadd_intro(sqrt_nonneg, Sqrt(4*t(arb_n)*t(arb_n)+1)) # 0<= Sqrt(4*t(arb_n)*t(arb_n)+1)

step_a = add_of(le(0,Sqrt(4*t(arb_n)*t(arb_n)+1)),1) # 1 <=  Sqrt(4*t(arb_n)*t(arb_n)+1) + 1


propadd_ineq(lt(0,1),[]) # 0 < 1
step_b = ineq_trans(lt(0,1),le(1, Sqrt(4*t(arb_n)*t(arb_n)+1)+1)) #0 <  Sqrt(4*t(arb_n)*t(arb_n)+1) + 1  by transitivity


propadd_ineq(lt(0,2),[]) # 0 < 2
step_c = divide_inequality( lt(0, Sqrt(4*t(arb_n)*t(arb_n)+1)+1 ) , 2) # dividing by positive number preserves inequality, and 0 < (Sqrt(4*t(arb_n)*t(arb_n)+1) + 1)/2

propadd_simplify( step_c ) #temp

induction( t_pos, [[assumption_t0]] , [[t_def(arb_n).simplify()]] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-89a43f12379e> in <module>
#       3     return lt(0,t(n))
#       4
# ----> 5 Prop = known_truth #Start with known truth
#       6
#       7 propadd_assumption(assumption_t0) #Assume t_0 = 1
#
# NameError: name 'known_truth' is not defined

# %% [markdown]
# ## 2. Equivalence of two method expressions

# %%
#Basic Setting
xknown_truth = {eq_refl,eq_sym,eq_to_le,eq_trans}
Prop = known_truth.copy()
Var = set()



t = ScalarSequence('t') #theta

x = Sequence('x')
y = Sequence('y')


X = Sequence('X') #For equivalent formulation
Y = Sequence('Y')
Z = Sequence('Z')


f = Function('f')
g = Operator('g') # Grdaient f
k = IterationCount('k')
L = Scalar('L')   # L-smoothness

# %%
#Define theta
t = ScalarSequence('t')

assumption_t0 = Equal(t(0),1)
def t_def(n):
  return Equal(t(n+1), 1/2*(Sqrt(4*t(n)*t(n)+1) +1))

Prop.add(assumption_t0)
Prop.add(t_def)


def t_rel(n):
  return Equal( t(n+1)*t(n+1) - t(n+1), t(n)*t(n) )


#Fomulation 1

assumption1 = Equal(t(0),1)
assumption2 = Equal(y(0),x(0))

def form1eq1(n):
  return Equal(y(n+1), x(n)-1/L*g(x(n)))

def form1eq2(n):
  return Equal(x(n+1) , y(n+1) + (t(n)-1)/t(n+1)*(y(n+1)-y(n)))


Prop.update([t_def,assumption1,assumption2,form1eq1,form1eq2])

# %%
#Formulation 2
assumption3 = Equal(Y(0) , X(0))
assumption4 = Equal(Z(0) , X(0))
assumption5 = Equal(x(0) , X(0))
assumption6 = Equal(y(0) , Y(0))


def form2eq1(n):
  return Equal(Y(n+1), X(n) - 1/L*g(X(n)))

def form2eq2(n):
  return Equal(Z(n+1), Z(n) - t(n)/L*g(x(n)))

def form2eq3(n):
  return Equal(X(n+1), (1- 1/t(n+1))*Y(n+1) + 1/t(n+1)*Z(n+1) )


Prop.update([assumption3, assumption4, assumption5, assumption6, form2eq1, form2eq2, form2eq3])

# %%
#Our goals

def x_equiv(n):
    return Equal(x(n),X(n))

def y_equiv(n):
    return Equal(y(n),Y(n))

xy_equiv = prop_and([x_equiv,y_equiv])

#induction(xy_equiv, [[],[]], [[],[]])

# %% [markdown]
# ### y-equivalence (under x assumptions)

# %%
Prop.add(Equal(x(arb_n),X(arb_n)))
propadd_intro(form1eq1,arb_n)
propadd_intro(form2eq1,arb_n)
induction(y_equiv,[[]],[[form1eq1(arb_n),form2eq1(arb_n),Equal(x(arb_n),X(arb_n))]])
# Out:
# Failed to verify
# Failed to verify
# case 0 : False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-1a1db8563ab1> in <module>
#       2 propadd_intro(form1eq1,arb_n)
#       3 propadd_intro(form2eq1,arb_n)
# ----> 4 induction(y_equiv,[[]],[[form1eq1(arb_n),form2eq1(arb_n),Equal(x(arb_n),X(arb_n))]])
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in induction(prop, proof_0, proof_succ)
#     214         case_succ.append(prop(arb_n + 1))
#     215
# --> 216     case_succ_istrue = verify(prop_and(case_succ), proof_succ)
#     217     print(f'case succ : {case_succ_istrue} ')
#     218
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      27         return verify_lt(prop, proof)
#      28     if isinstance(prop, prop_and ):
# ---> 29         return verify_and(prop, proof)
#      30
#      31
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_and(props, proofs)
#      34     result = True
#      35     for i in range(len(props.prop_list)):
# ---> 36         result = result and verify(props.prop_list[i], proofs[i])
#      37     return result
#      38
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify(prop, proof)
#      21
#      22     if isinstance(prop, Equal):
# ---> 23         return verify_equality(prop, proof)
#      24     if isinstance(prop, le):
#      25         return verify_le(prop, proof)
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_equality(eq, proof)
#      77         else: raise TypeError(f'Cannot use the following step: {step}' )
#      78       else:
# ---> 79         raise TypeError( f'Should first verify the current step: {step}')
#      80
#      81   #Check if LHS-RHS = 0
#
# TypeError: Should first verify the current step: y^{1+arb_n} = -L**{-1} * g(x^{arb_n}) + x^{arb_n}

# %% [markdown]
# ### x_equivalence (under x_assumptions)

# %%
propadd_intro(y_equiv,arb_n)
propadd_intro(y_equiv,arb_n+1)
propadd_intro(form1eq2,arb_n)
propadd_intro(form2eq2,arb_n)
propadd_intro(form2eq3, arb_n-1)
propadd_intro(form2eq3, arb_n)
Prop.add(t_rel(arb_n))
Prop.add(eq_sym(t_rel(arb_n)))


def_z_n = Equal(Z(arb_n), t(arb_n)*X(arb_n) + (1-t(arb_n))*Y(arb_n))
propadd_eq(def_z_n, [form2eq3(arb_n-1) ])

verify(x_equiv(arb_n+1),[form2eq3(arb_n),form2eq2(arb_n),def_z_n,form1eq2(arb_n), y_equiv(arb_n+1),y_equiv(arb_n),form2eq1(arb_n),t_def(arb_n),eq_sym(t_rel(arb_n))])
# Out:
# Failed to verify
# Failed to verify
# Failed to verify
# Failed to verify
# Failed to verify
# Failed to verify
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-55096e1ac123> in <module>
#      10
#      11 def_z_n = Equal(Z(arb_n), t(arb_n)*X(arb_n) + (1-t(arb_n))*Y(arb_n))
# ---> 12 propadd_eq(def_z_n, [form2eq3(arb_n-1) ])
#      13
#      14 verify(x_equiv(arb_n+1),[form2eq3(arb_n),form2eq2(arb_n),def_z_n,form1eq2(arb_n), y_equiv(arb_n+1),y_equiv(arb_n),form2eq1(arb_n),t_def(arb_n),eq_sym(t_rel(arb_n))])
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in propadd_eq(eq, proof)
#     254
#     255 def propadd_eq(eq,proof):
# --> 256   if verify_equality(eq,proof) == True:
#     257     Prop.add(eq)
#     258     #print(f'{eq} added to Proposition data')
#
# ~\내 드라이브(jacksuhkr@gmail.com)\jupyter notebook\[[[ Verify ]]]\formal_proof_verification\Verifier.py in verify_equality(eq, proof)
#      77         else: raise TypeError(f'Cannot use the following step: {step}' )
#      78       else:
# ---> 79         raise TypeError( f'Should first verify the current step: {step}')
#      80
#      81   #Check if LHS-RHS = 0
#
# TypeError: Should first verify the current step: X^{arb_n} = ( 1-t_{arb_n}**{-1} ) * Y^{arb_n} + t_{arb_n}**{-1} * Z^{arb_n}

# %%
def stepp(result,step):
    if step in Prop:
        print(f'before: {result}\n step: {step}')
        tmp_res = result
        if isinstance(step, Equal):                 #substitution
          try: result = result.substitute(step)
          except: pass
          print(f'after : {result}\n  changed : {not tmp_res == result} \n ')
        elif isinstance(step, lemma):               #add lemma
          propadd_eq(lemma.claim, lemma.proof)
        else: raise TypeError(f'Cannot use the following step: {step}' )
    else:
        raise TypeError( f'Should first verify the current step: {step}')

    try:
        print(f'simplified to : {result.simplify()}\n')
        return result.simplify()
    except:
        print('not simplified \n')
        return result

# %%
s = [0]*100
s[0] = X(arb_n+1)-x(arb_n+1)

proofff = [form2eq3(arb_n),form1eq2(arb_n), y_equiv(arb_n+1),y_equiv(arb_n), form2eq2(arb_n), def_z_n,form2eq1(arb_n),x_equiv(arb_n)]
for i in range(len(proofff)):
    s[i+1] = stepp(s[i],proofff[i])


# s[1] = stepp(s[0], form2eq3((arb_n)) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f08dbe9d4cdf> in <module>
#       4 proofff = [form2eq3(arb_n),form1eq2(arb_n), y_equiv(arb_n+1),y_equiv(arb_n), form2eq2(arb_n), def_z_n,form2eq1(arb_n),x_equiv(arb_n)]
#       5 for i in range(len(proofff)):
# ----> 6     s[i+1] = stepp(s[i],proofff[i])
#       7
#       8
#
# <ipython-input-62-a31f34515def> in stepp(result, step)
#      11         else: raise TypeError(f'Cannot use the following step: {step}' )
#      12     else:
# ---> 13         raise TypeError( f'Should first verify the current step: {step}')
#      14
#      15     try:
#
# TypeError: Should first verify the current step: X^{1+arb_n} = ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}

# %% [markdown]
# ---
# ## Lyapunov analysis
# $$ x^{k+1} = x^k - \frac{1}{L} \nabla f(x^k) $$
# ---

# %% [markdown]
# ## Define materials

# %%
x = Sequence('x') # seqeunce generated by gradient descent
y = Sequence('y')
z = Sequence('z')
f = Function('f')
g = Operator('g') # Grdaient f
k = IterationCount('k')
L = Scalar('L')   # smoothness parameter
A = ScalarSequence('A')
t = ScalarSequence('t')

# %%
x_star = x('\star')
f_star = f(x_star)

# %% [markdown]
# ### Define Lyapunov function
# $$ \Phi(n) = A_n ( f(x^n) - f^\star ) + \frac{L}{2} \left\| z^n - x^\star \right\|^2 $$

# %%
def Lypunov(n):
    return A(n) * ( f(x(n)) - f_star )+ L/2 * Square( z(n)-x_star )

# %% [markdown]
# ## The 'proof' we want to show is
# \begin{align*}
#     \Phi(k+1) - \Phi(k)
#     = \lambda_1 \left( f(y^k) - f^\star + \left\langle \nabla f(x^k) , x^\star - x^k \right \rangle \right)
#     + \lambda_2 \left( f(y^{k}) - f(x^k) + \left\langle \nabla f (y^k) , x^{k} - y^k \right\rangle \right)
#     + \lambda_3  \left( f(x^{k+1}) - f(y^k) + \left\langle \nabla f (y^k) , x^{k+1} - y^k \right\rangle + \frac{L}{2} \left\| y^k - x^{k+1} \right\|^2  \right)
#     - \lambda_4 \frac{1}{2L} \left\| \nabla f (x^k) \right\|^2
# \end{align*}
# ### where
# \begin{align*}
#     \lambda_1 &= A_{k+1} - A_k,  \qquad
#     \lambda_2 = A_{k},  \qquad
#     \lambda_3 = A_{k+1},  \qquad
#     \lambda_4 = \frac{A_{k+1} - (A_{k}-A_{k+1})^2}{2 L},  \qquad
# \end{align*}

# %%
lambda_1 = A(k+1) - A(k)
lambda_2 = A(k)
lambda_3 = A(k+1)
lambda_4 = (A(k+1)-(A(k)-A(k+1))**2)/(2*L)

# %%
ineq1 = f(y(k)) - f_star + IP(g(y(k)), x_star - y(k))
ineq2 = f(y(k)) - f(x(k)) + IP(g(y(k)),x(k)-y(k))
ineq3 = f(x(k+1)) - f(y(k)) - IP(g(y(k)), x(k+1) - y(k)) - L/2 * Square( x(k+1) - y(k) )
ineq4 = -Square(g(y(k)))

# %%
LHS = Lypunov(k+1) - Lypunov(k)
RHS = lambda_1 * ineq1 + lambda_2 * ineq2 + lambda_3 * ineq3 + lambda_4 * ineq4

# %%
LHS - RHS
# Out:
# ( - f(x^{\star})+f(x^{1+k}) ) A_{1+k}+( -(-A_{1+k}+A_{k})^{2}+A_{1+k} ) 2 L^{-1} || g(y^{k}) ||^2-( - < -y^{k} + x^{1+k}, g(y^{k}) >- f(y^{k})-0.5 L || -y^{k} + x^{1+k} ||^2+f(x^{1+k}) ) A_{1+k}-( - f(x^{\star})+< -y^{k} + x^{\star}, g(y^{k}) >+f(y^{k}) ) ( -A_{k}+A_{1+k} )-( - f(x^{\star})+f(x^{k}) ) A_{k}-( - f(x^{k})+< -y^{k} + x^{k}, g(y^{k}) >+f(y^{k}) ) A_{k}-0.5 L || -x^{\star} + z^{k} ||^2+0.5 L || -x^{\star} + z^{1+k} ||^2

# %%
( LHS - RHS ).simplify()
# Out:
# ( -0.5 A_{1+k}^{2} L^{-1}-0.5 A_{k}^{2} L^{-1}+0.5 A_{1+k} L^{-1}+A_{1+k} A_{k} L^{-1} ) || g(y^{k}) ||^2+( -A_{1+k}+A_{k} ) < g(y^{k}), x^{\star} >-0.5 L || z^{k} ||^2-A_{1+k} L < x^{1+k}, y^{k} >-A_{k} < g(y^{k}), x^{k} >-L < x^{\star}, z^{1+k} >+0.5 A_{1+k} L || x^{1+k} ||^2+0.5 A_{1+k} L || y^{k} ||^2+0.5 L || z^{1+k} ||^2+A_{1+k} < g(y^{k}), x^{1+k} >+L < x^{\star}, z^{k} >

# %% [markdown]
# ## Substituting definitions and simplifying...

# %%
def z_def(n) :
    statement = Equal(z(n+1), z(n) - (A(n+1) - A(n))/L * g( y(n) ) )
    statement.truth = 'Axiom'
    return statement

def x_def(n) :
    statement = Equal(x(n+1), y(n) - 1/L * g( y(n) ) )
    statement.truth = 'Axiom'
    return statement

def A_def(n):
    statement = Equal(A(n+1), A(n)+t(n))
    statement.truth = 'Axiom'
    return statement

# %%
def x_rel(n) :
    statement = Equal(x(n), A(n+1)/A(n) * y(n) - ( A(n+1)/A(n) - 1 ) * z(n) )
    statement.truth = 'Axiom'
    return statement

# %%
( LHS - RHS ).substitute(z_def(k)).substitute(x_def(k)).substitute(x_rel(k)).substitute(A_def(k)).simplify()
# Out:
# 0
