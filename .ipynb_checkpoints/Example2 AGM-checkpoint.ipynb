# %%
from VerifyObjects import *
from VerifyRelation import *
from Verifier import *

# %% [markdown]
# # Example2: Accelerated Gradient Descent

# %% [markdown]
# ## 1. Positiveness of $\theta_k$

# %%
Prop.clear()

# %% [markdown]
# ### Proving the alternative form of $\theta_k$ satisfies the recurrence relation

# %%
t = ScalarSequence('t')

def t_rel(n):
    return Equal( t(n+1)*t(n+1) - t(n+1), t(n)*t(n) )

# %% [markdown]
# #### Defining the alternative form

# %%
assumption_t0 = Equal(t(0),1)
def t_def(n):
    return Equal(t(n+1), 1/2*(Sqrt(4*t(n)*t(n)+1) +1))

Prop.add( assumption_t0 )
Prop.add( t_def )

propadd_assumption(t_def)
propadd_intro(t_def,arb_n)

# %% [markdown]
# #### Verifying the equivalence

# %%
verify(t_rel, [t_def(arb_n)])
# Out:
# True

# %% [markdown]
# ## Verifying the positiveness of $\theta_k$

# %% [markdown]
# ###  Declaring our goal

# %%
def t_pos(n): return lt(0,t(n))

# %% [markdown]
# #### Definition of $\theta_k$

# %%
Prop.clear()

# Assume t_0 = 1 and the recurrence relation
propadd_assumption(assumption_t0) 
propadd_assumption(t_def)    

# Specifically we consider t(0), t(arb_n) to be true
propadd_intro(t_def, 0)       
propadd_intro(t_def, arb_n)

# %%
propadd_assumption(sqrt_nonneg) # sqrt is nonneg
propadd_intro(sqrt_nonneg, Sqrt(4*t(arb_n)*t(arb_n)+1)) # 0<= Sqrt(4*t(arb_n)*t(arb_n)+1)

step_a = add_of(le(0,Sqrt(4*t(arb_n)*t(arb_n)+1)),1) # 1 <=  Sqrt(4*t(arb_n)*t(arb_n)+1) + 1

# %%
propadd_ineq(lt(0,1),[]) # 0 < 1

step_b = ineq_trans(lt(0,1),le(1, Sqrt(4*t(arb_n)*t(arb_n)+1)+1)) #0 <  Sqrt(4*t(arb_n)*t(arb_n)+1) + 1  by transitivity

# %%
propadd_ineq(lt(0,2),[]) # 0 < 2
step_c = divide_inequality( lt(0, Sqrt(4*t(arb_n)*t(arb_n)+1)+1 ) , 2) # dividing by positive number preserves inequality, and 

propadd_simplify( step_c ) #temp

# %%
induction( t_pos, [[assumption_t0]] , [[t_def(arb_n).simplify()]] )
# Out:
# case 0 : True
# case succ : True

# %% [markdown]
# ## 2. Equivalence of two method expressions

# %% [markdown]
# ### Basic Setting

# %%
Prop.clear()

x = Sequence('x')
y = Sequence('y')

X = Sequence('X') #For equivalent formulation
Y = Sequence('Y')
Z = Sequence('Z')

f = Function('f')
g = Operator('g') # Grdaient f
k = IterationCount('k')
L = Scalar('L')   # L-smoothness

# %%
#Define theta
t = ScalarSequence('t')

assumption_t0 = Equal(t(0),1)
def t_def(n):
    return Equal(t(n+1), 1/2*(Sqrt(4*t(n)*t(n)+1) +1))

Prop.add(assumption_t0)
Prop.add(t_def)

# %%
#Fomulation 1

assumption1 = Equal(t(0),1)
assumption2 = Equal(y(0),x(0))

def form1eq1(n):
    return Equal(y(n+1), x(n)-1/L*g(x(n)))

def form1eq2(n):
    return Equal(x(n+1) , y(n+1) + (t(n)-1)/t(n+1)*(y(n+1)-y(n)))

Prop.update([t_def,assumption1,assumption2,form1eq1,form1eq2])


#Formulation 2
assumption3 = Equal(Y(0) , X(0))
assumption4 = Equal(Z(0) , X(0))
assumption5 = Equal(x(0) , X(0))
assumption6 = Equal(y(0) , Y(0))


def form2eq1(n):
    return Equal(Y(n+1), X(n) - 1/L*g(X(n)))

def form2eq2(n):
    return Equal(Z(n+1), Z(n) - t(n)/L*g(x(n)))

def form2eq3(n):
    return Equal(X(n+1), (1- 1/t(n+1))*Y(n+1) + 1/t(n+1)*Z(n+1) )


Prop.update([assumption3, assumption4, assumption5, assumption6, form2eq1, form2eq2, form2eq3])
tmp = Prop.copy()

# %%
#Our goals

def x_equiv(n):
    return Equal(x(n),X(n))

def y_equiv(n):
    return Equal(y(n),Y(n))

xy_equiv = prop_and([x_equiv,y_equiv])

#induction(xy_equiv, [[],[]], [[],[]])

# %% [markdown]
# y-equivalence (under x assumptions)

# %%
Prop.add(Equal(x(arb_n),X(arb_n)))
propadd_intro(form1eq1,arb_n)
propadd_intro(form2eq1,arb_n)
induction(y_equiv,[[]],[[form1eq1(arb_n),form2eq1(arb_n),Equal(x(arb_n),X(arb_n))]])
# Out:
# case 0 : True
# case succ : True

# %% [markdown]
# x_equivalence (under x_assumptions)

# %%
# induction hypothersis
Prop.add( y_equiv(arb_n) )
Prop.add( y_equiv(arb_n+1) )
Prop.add( x_equiv(arb_n) )

propadd_intro( form1eq2, arb_n )
propadd_intro( form2eq2, arb_n )
propadd_intro( form2eq3, arb_n-1 )
propadd_intro( form2eq3, arb_n )

def_z_n = Equal(Z(arb_n), t(arb_n)*X(arb_n) + (1-t(arb_n))*Y(arb_n))
propadd_eq(def_z_n, [form2eq3(arb_n-1) ])

# %%
def stepp(result,step):
    if step in Prop:
        print(f'before: {result}\n step: {step}')
        tmp_res = result
        if isinstance(step, Equal):                 #substitution
            try: result = result.substitute(step)
            except: pass
            print(f'after : {result}\n  changed : {not tmp_res == result} \n ')
        elif isinstance(step, lemma):               #add lemma
              propadd_eq(lemma.claim, lemma.proof)
        else: raise TypeError(f'Cannot use the following step: {step}' )
    else:
        raise TypeError( f'Should first verify the current step: {step}')

    try:
        print(f'simplified to : {result.simplify()}\n')
        return result.simplify()
    except:
        print('not simplified \n')
        return result

# %%
s = [0] * 100
s[0] = X(arb_n+1) - x(arb_n+1)

proofff = [form2eq3(arb_n),form1eq2(arb_n), y_equiv(arb_n+1),y_equiv(arb_n), form2eq2(arb_n), def_z_n,form2eq1(arb_n),x_equiv(arb_n)]
for i in range(len(proofff)):
     s[i+1] = stepp(s[i],proofff[i])

verify( x_equiv(arb_n+1), proofff )
# Out:
# before: -x^{1+arb_n} + X^{1+arb_n}
#  step: X^{1+arb_n} = ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
# after : ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n}-x^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#   changed : True
#
# simplified to : ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n}-x^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#
# before: ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n}-x^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#  step: x^{1+arb_n} = ( 1+( -1+t_{arb_n} ) * t_{1+arb_n}**{-1} ) * y^{1+arb_n}-( -1+t_{arb_n} ) * t_{1+arb_n}**{-1} * y^{arb_n}
# after : ( -1+t_{arb_n} ) * t_{1+arb_n}**{-1} * y^{arb_n} + ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n}-( 1+( -1+t_{arb_n} ) * t_{1+arb_n}**{-1} ) * y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#   changed : True
#
# simplified to : ( -1-t_{1+arb_n}**{-1} * t_{arb_n}+t_{1+arb_n}**{-1} ) * y^{1+arb_n} + ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * y^{arb_n} + ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#
# before: ( -1-t_{1+arb_n}**{-1} * t_{arb_n}+t_{1+arb_n}**{-1} ) * y^{1+arb_n} + ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * y^{arb_n} + ( 1-t_{1+arb_n}**{-1} ) * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#  step: y^{1+arb_n} = Y^{1+arb_n}
# after : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#   changed : True
#
# simplified to : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#
# before: ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#  step: y^{arb_n} = Y^{arb_n}
# after : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#   changed : True
#
# simplified to : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#
# before: ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{1+arb_n}
#  step: Z^{1+arb_n} = -L**{-1} * t_{arb_n} * g(x^{arb_n}) + Z^{arb_n}
# after : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{arb_n}
#   changed : True
#
# simplified to : ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{arb_n}
#
# before: ( -t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * Z^{arb_n}
#  step: Z^{arb_n} = ( 1-t_{arb_n} ) * Y^{arb_n} + t_{arb_n} * X^{arb_n}
# after : ( ( 1-t_{arb_n} ) * t_{1+arb_n}**{-1}-t_{1+arb_n}**{-1}+t_{1+arb_n}**{-1} * t_{arb_n} ) * Y^{arb_n}-L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * t_{arb_n} * X^{arb_n}
#   changed : True
#
# simplified to : -L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * t_{arb_n} * X^{arb_n}
#
# before: -L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n})-t_{1+arb_n}**{-1} * t_{arb_n} * Y^{1+arb_n} + t_{1+arb_n}**{-1} * t_{arb_n} * X^{arb_n}
#  step: Y^{1+arb_n} = -L**{-1} * g(X^{arb_n}) + X^{arb_n}
# after : -L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n}) + L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(X^{arb_n})
#   changed : True
#
# simplified to : -L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n}) + L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(X^{arb_n})
#
# before: -L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(x^{arb_n}) + L**{-1} * t_{1+arb_n}**{-1} * t_{arb_n} * g(X^{arb_n})
#  step: x^{arb_n} = X^{arb_n}
# after : O
#   changed : True
#
# simplified to : O
# True

# %% [markdown]
# ## Combine together to complete induction process

# %%
propadd_intro(form1eq1, arb_n)
propadd_intro(form1eq2, arb_n)
propadd_intro(form2eq1, arb_n)
propadd_intro(form2eq2, arb_n)
propadd_intro(form2eq3, arb_n-1)
propadd_intro(form2eq3, arb_n)

def_z_n = Equal( Z(arb_n), t(arb_n) * X(arb_n) + (1-t(arb_n)) * Y(arb_n) )
propadd_eq( def_z_n, [ form2eq3(arb_n-1) ] )

# %%
proof_y = [ form1eq1(arb_n), form2eq1(arb_n), Equal(x(arb_n), X(arb_n)) ]
lem_y_equiv = lemma( y_equiv(arb_n+1), proof_y )
proof_x = [ lem_y_equiv, form2eq3(arb_n), form1eq2(arb_n), y_equiv(arb_n+1), y_equiv(arb_n), form2eq2(arb_n), def_z_n, form2eq1(arb_n), x_equiv(arb_n) ]

induction( xy_equiv, [[],[]], [proof_x, proof_y] )
# Out:
# case 0 : True
# case succ : True

# %% [markdown]
# ---
# ## 3. Lyapunov analysis
# ---

# %% [markdown]
# ## Define materials

# %%
Prop.clear()

# %%
x = Sequence('x') # seqeunce generated by gradient descent
y = Sequence('y')
z = Sequence('z')
f = Function('f')
g = Operator('g') # Grdaient f
L = Scalar('L')   # smoothness parameter
A = ScalarSequence('A')
t = ScalarSequence('t')

# %%
x_star = x('\star')
f_star = f(x_star)

# %% [markdown]
# ### Define Lyapunov function
# $$ \Phi(n) = A_n ( f(x^n) - f^\star ) + \frac{L}{2} \left\| z^n - x^\star \right\|^2 $$

# %%
def Lypunov(n): return A(n) * ( f(x(n)) - f_star )+ L/2 * Square( z(n)-x_star )

# %% [markdown]
# ## The 'proof' we want to show is
# \begin{align*}
#     \Phi(k+1) - \Phi(k)
#     = \lambda_1 \left( f(y^k) - f^\star + \left\langle \nabla f(x^k) , x^\star - x^k \right \rangle \right)
#     + \lambda_2 \left( f(y^{k}) - f(x^k) + \left\langle \nabla f (y^k) , x^{k} - y^k \right\rangle \right)
#     + \lambda_3  \left( f(x^{k+1}) - f(y^k) + \left\langle \nabla f (y^k) , x^{k+1} - y^k \right\rangle + \frac{L}{2} \left\| y^k - x^{k+1} \right\|^2  \right)
#     - \lambda_4  \left\| \nabla f (y^k) \right\|^2
# \end{align*}
# ### where
# \begin{align*}
#     \lambda_1 &= A_{k+1} - A_k,  \qquad
#     \lambda_2 = A_{k},  \qquad
#     \lambda_3 = A_{k+1},  \qquad
#     \lambda_4 = \frac{A_{k+1} - (A_{k}-A_{k+1})^2}{2 L},  \qquad
# \end{align*}

# %%
def lambda_1(k): return A(k+1) - A(k)
def lambda_2(k): return A(k)
def lambda_3(k): return A(k+1)
def lambda_4(k): return (A(k+1)-(A(k)-A(k+1))**2)/(2*L)

# %%
def ineq1(k): return f(y(k)) - f_star + IP(g(y(k)), x_star - y(k))
def ineq2(k): return f(y(k)) - f(x(k)) + IP(g(y(k)),x(k)-y(k))
def ineq3(k): return f(x(k+1)) - f(y(k)) - IP(g(y(k)), x(k+1) - y(k)) - L/2 * Square( x(k+1) - y(k) )
def ineq4(k): return -Square(g(y(k)))

# %%
def LHS(k): return Lypunov(k+1) - Lypunov(k)
def RHS(k): return lambda_1(k) * ineq1(k) + lambda_2(k) * ineq2(k) + lambda_3(k) * ineq3(k) + lambda_4(k) * ineq4(k)

# %%
def target(k): return Equal(LHS(k), RHS(k))

# %%
verify(target, [])
# Out:
# False

# %% [markdown]
# ### Equations substituting for proof

# %%
def z_def(n) :
    statement = Equal(z(n+1), z(n) - (A(n+1) - A(n))/L * g( y(n) ) )
    statement.istrue = 1
    return statement

def x_def(n) :
    statement = Equal(x(n+1), y(n) - 1/L * g( y(n) ) )
    statement.istrue = 1
    return statement

def A_def(n):
    statement = Equal(A(n+1), A(n)+t(n))
    statement.istrue = 1
    return statement

# %%
def x_rel(n) :
    statement = Equal(x(n), A(n+1)/A(n) * y(n) - ( A(n+1)/A(n) - 1 ) * z(n) )
    statement.istrue = 1
    return statement

# %% [markdown]
# ### Add the definitions and relations to prop

# %%
Prop.clear()
Prop.update( [z_def, x_def, x_rel, A_def] )

# %% [markdown]
# ### Add the definitions and relations to prop for arbitrary n case

# %%
propadd_intro(z_def, arb_n)
propadd_intro(x_def, arb_n)
propadd_intro(x_rel, arb_n)
propadd_intro(A_def, arb_n)

# %%
verify(target, [z_def(arb_n), x_def(arb_n), x_rel(arb_n), A_def(arb_n)])
# Out:
# True

# %% [markdown]
# ## If we print out

# %%
(LHS(arb_n) - RHS(arb_n)).simplify()
# Out:
# ( -0.5 A_{1+arb_n}^{2} L^{-1}-0.5 A_{arb_n}^{2} L^{-1}+0.5 A_{1+arb_n} L^{-1}+A_{1+arb_n} A_{arb_n} L^{-1} ) || g(y^{arb_n}) ||^2+( -A_{1+arb_n}+A_{arb_n} ) < g(y^{arb_n}), x^{\star} >-0.5 L || z^{arb_n} ||^2-A_{1+arb_n} L < x^{1+arb_n}, y^{arb_n} >-A_{arb_n} < g(y^{arb_n}), x^{arb_n} >-L < x^{\star}, z^{1+arb_n} >+0.5 A_{1+arb_n} L || x^{1+arb_n} ||^2+0.5 A_{1+arb_n} L || y^{arb_n} ||^2+0.5 L || z^{1+arb_n} ||^2+A_{1+arb_n} < g(y^{arb_n}), x^{1+arb_n} >+L < x^{\star}, z^{arb_n} >

# %%
( LHS(arb_n) - RHS(arb_n) ).substitute(z_def(arb_n)).substitute(x_def(arb_n)).substitute(x_rel(arb_n)).substitute(A_def(arb_n)).simplify()
# Out:
# 0

# %% [markdown]
# # In old grammer

# %%
k = IterationCount('k')

# %%
lambda_1 = A(k+1) - A(k)
lambda_2 = A(k)
lambda_3 = A(k+1)
lambda_4 = (A(k+1)-(A(k)-A(k+1))**2)/(2*L)

# %%
ineq1 = f(y(k)) - f_star + IP(g(y(k)), x_star - y(k))
ineq2 = f(y(k)) - f(x(k)) + IP(g(y(k)),x(k)-y(k))
ineq3 = f(x(k+1)) - f(y(k)) - IP(g(y(k)), x(k+1) - y(k)) - L/2 * Square( x(k+1) - y(k) )
ineq4 = -Square(g(y(k)))

# %%
LHS = Lypunov(k+1) - Lypunov(k)
RHS = lambda_1 * ineq1 + lambda_2 * ineq2 + lambda_3 * ineq3 + lambda_4 * ineq4

# %%
LHS - RHS
# Out:
# ( - f(x^{\star})+f(x^{1+k}) ) A_{1+k}+( -(-A_{1+k}+A_{k})^{2}+A_{1+k} ) 2 L^{-1} || g(y^{k}) ||^2-( - < -y^{k} + x^{1+k}, g(y^{k}) >- f(y^{k})-0.5 L || -y^{k} + x^{1+k} ||^2+f(x^{1+k}) ) A_{1+k}-( - f(x^{\star})+< -y^{k} + x^{\star}, g(y^{k}) >+f(y^{k}) ) ( -A_{k}+A_{1+k} )-( - f(x^{\star})+f(x^{k}) ) A_{k}-( - f(x^{k})+< -y^{k} + x^{k}, g(y^{k}) >+f(y^{k}) ) A_{k}-0.5 L || -x^{\star} + z^{k} ||^2+0.5 L || -x^{\star} + z^{1+k} ||^2

# %%
( LHS - RHS ).simplify()
# Out:
# ( -0.5 A_{1+k}^{2} L^{-1}-0.5 A_{k}^{2} L^{-1}+0.5 A_{1+k} L^{-1}+A_{1+k} A_{k} L^{-1} ) || g(y^{k}) ||^2+( -A_{1+k}+A_{k} ) < g(y^{k}), x^{\star} >-0.5 L || z^{k} ||^2-A_{1+k} L < x^{1+k}, y^{k} >-A_{k} < g(y^{k}), x^{k} >-L < x^{\star}, z^{1+k} >+0.5 A_{1+k} L || x^{1+k} ||^2+0.5 A_{1+k} L || y^{k} ||^2+0.5 L || z^{1+k} ||^2+A_{1+k} < g(y^{k}), x^{1+k} >+L < x^{\star}, z^{k} >

# %% [markdown]
# ## Substituting definitions and simplifying...

# %%
( LHS - RHS ).substitute(z_def(k)).substitute(x_def(k)).substitute(x_rel(k)).substitute(A_def(k)).simplify()
# Out:
# 0
