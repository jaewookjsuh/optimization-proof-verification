# %%
from VerifyObjects import *
from VerifyRelation import *
from Verifier import *

# %%
Prop.clear()

# %%
f = Function('f', Vector, Scalar)

# %%
g = Gradient(f)

# %%
g
# Out:
# \nabla f

# %%
type(g)
# Out:
# VerifyObjects.Gradient

# %%
g.name
# Out:
# '▽f'
