# %%
from VerifyObjects import *
from VerifyRelation import *
from Verifier import *

# %%
class Norm(Scalar):
    def __init__(self, inside):
        self.inside = inside
        self.base = self

    def __pow__(self, exponent):
        if exponent==2:
            return NS(self.inside)
        else:
            # return self.base**exponent XXX 요 한줄 때문에
            return super().__pow__(exponent)
        
    def __str__(self):
        s = "|| " + str(self.inside) + " ||"
        return s

    # def __eq__(self, other):
    #     return isinstance(other, Norm) and self.inside == other.inside

    # xxx
    # def __hash__(self):
    #     return hash( str(type(self)) + str(self.inside) )

# %%
def new_expand(self):
    expanded_base = self.base.expand()
    if type( expanded_base ) != ScalarAdd:
        return self
        # return expanded_base ** self.exponent
    # exp = self.exponent
    # if is_number(self.exponent):
    #     if int(exp)==exp and exp>0:
    #         return self.poly_expansion(expanded_base, exp)
    return self

# %%
v = Vector('v')
nv = Norm(v)
w = 1/Norm(v)

# %%
new_expand(w)
# Out:
# || v ||^{-1}

# %%
w.exponent
# Out:
# -1

# %%
w.base.expand()
# Out:
# || v ||

# %%
a = Scalar('a')
a.base.expand() ** (-1)
# Out:
# a^{-1}

# %%
nv**4
# Out:
# || v ||^{4}

# %%
nv ** (-1)
# Out:
# || v ||^{-1}

# %%
w.base ** (-1)

# %%
w.base ** w.exponent

# %%
Norm(v).simplify()
1/Norm(v)
type(1/Norm(v))

# %%
(1/Norm(v)).base.expand()

# %%
(1/Norm(v)).expand()

# %%
display( hash( Norm(v) ) )

# %%
display( hash( v ) )

# %%
display( hash( str(Norm(v).inside) ) )

# %%
Norm(v).simplify()

# %%
( 1/ NS(v) ).simplify()

# %%
display( ( 1/Norm(v) ).simplify() )

# %%
v = Vector('v')

nv = Norm(v)
display(nv)
display( type(nv) )
display(NS(v))
display(nv**2)
display(hash(nv))
type(nv**2)
Norm(v) == Norm(-v)

# %%
hash( str(type(nv)) + str(nv) )
# Out:
# 4594591808225234590

# %%
v = Vector('v')

Norm(v).simplify()
1/Norm(v)
type(1/Norm(v))
# Out:
# VerifyObjects.ScalarPow

# %%
(1/Norm(v)).base.expand()
# Out:
# || v ||

# %%
(1/Norm(v)).expand()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
display( hash( Norm(v) ) )
# Out:
# -2438308110041279763

# %%
display( hash( v ) )

# %%
display( hash( str(Norm(v).inside) ) )

# %%
Norm(v).simplify()

# %%
( 1/ NS(v) ).simplify()

# %%
display( ( 1/Norm(v) ).simplify() )

# %%
v = Vector('v')

nv = Norm(v)
display(nv)
display( type(nv) )
display(NS(v))
display(nv**2)
display(hash(nv))
type(nv**2)
Norm(v) == Norm(-v)

# %%
hash( str(type(nv)) + str(nv) )
# Out:
# 4594591808225234590

# %%
ineq_9_2_1 in Prop
# Out:
# False

# %%
ineq_9_2_1.lhs
# Out:
# \lambda_{k}

# %%
# ineq_9_2_1.rhs.simplify()

# %%
( Norm(x(k) - x(k-1))/ ( 2 * Norm( g(x(k)) - g(x(k-1)) ) )).simplify()
# Out:
# 0.5|| -x^{-1+k} + x^{k} |||| -▽f(x^{-1+k}) + ▽f(x^{k}) ||^{-1}
